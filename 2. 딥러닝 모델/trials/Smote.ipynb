# %% [markdown]
# # 라이브러리 세팅

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import RandomOverSampler  # 임포트 추가
from imblearn.over_sampling import SMOTE
import seaborn as sns

# %% [markdown]
# # 데이터 로드, csv파일 호출 명령어에서 csv 파일명이 바뀌었습니다. 이에 맞춰 clustered_data2 파일을 다운받으셔야합니다.

# %%
df = pd.read_csv("clustered_data2.csv")

features = [
    'activity_score', 'activity_steps', 'activity_inactive', 'activity_high',
    'activity_score_meet_daily_targets', 'activity_score_move_every_hour',
    'activity_daily_movement', 'activity_total'
]
X = df[features].values.astype(np.float32)
y = df['risk_level'].values.astype(np.int64)

# %% [markdown]
# # SMOTE 기법을 사용한 오버샘플링

# %%
# SMOTE 기법을 사용한 오버샘플링
smote = SMOTE(random_state=42)  # SMOTE로 교체
X_resampled, y_resampled = ros.fit_resample(X, y)

# %% [markdown]
# # 데이터 분할

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, stratify=y_resampled, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# # Tensor 변환 및 DataLoader 생성

# %%
train_dataset = TensorDataset(torch.tensor(X_train), torch.tensor(y_train))
val_dataset = TensorDataset(torch.tensor(X_val), torch.tensor(y_val))
test_dataset = TensorDataset(torch.tensor(X_test), torch.tensor(y_test))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64)
test_loader = DataLoader(test_dataset, batch_size=64)

# %% [markdown]
# # MLP 모델 정의

# %%
class RiskClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(8, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 4)  # 출력: 4단계 클래스
        )

    def forward(self, x):
        return self.net(x)

# 장치 설정 (GPU가 있으면 GPU 사용)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RiskClassifier().to(device)

# 손실 함수 및 옵티마이저 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 학습 루프
epochs = 50
train_loss_history, val_loss_history = [], []

for epoch in range(epochs):
    model.train()
    epoch_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    # 검증 손실 계산
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            val_outputs = model(X_val_batch)
            val_loss += criterion(val_outputs, y_val_batch).item()

    avg_train_loss = epoch_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)
    train_loss_history.append(avg_train_loss)
    val_loss_history.append(avg_val_loss)

    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/50 | Train Loss: 0.8903 | Val Loss: 0.5867
# Epoch 2/50 | Train Loss: 0.5094 | Val Loss: 0.4513
# Epoch 3/50 | Train Loss: 0.4258 | Val Loss: 0.4017
# Epoch 4/50 | Train Loss: 0.3830 | Val Loss: 0.3659
# Epoch 5/50 | Train Loss: 0.3576 | Val Loss: 0.3584
# Epoch 6/50 | Train Loss: 0.3407 | Val Loss: 0.3305
# Epoch 7/50 | Train Loss: 0.3251 | Val Loss: 0.3237
# Epoch 8/50 | Train Loss: 0.3140 | Val Loss: 0.3145
# Epoch 9/50 | Train Loss: 0.3038 | Val Loss: 0.3101
# Epoch 10/50 | Train Loss: 0.2947 | Val Loss: 0.2998
# Epoch 11/50 | Train Loss: 0.2861 | Val Loss: 0.2893
# Epoch 12/50 | Train Loss: 0.2782 | Val Loss: 0.2874
# Epoch 13/50 | Train Loss: 0.2717 | Val Loss: 0.2795
# Epoch 14/50 | Train Loss: 0.2649 | Val Loss: 0.2816
# Epoch 15/50 | Train Loss: 0.2590 | Val Loss: 0.2683
# Epoch 16/50 | Train Loss: 0.2526 | Val Loss: 0.2584
# Epoch 17/50 | Train Loss: 0.2465 | Val Loss: 0.2582
# Epoch 18/50 | Train Loss: 0.2403 | Val Loss: 0.2566
# Epoch 19/50 | Train Loss: 0.2359 | Val Loss: 0.2421
# Epoch 20/50 | Train Loss: 0.2292 | Val Loss: 0.2418
# Epoch 21/50 | Train Loss: 0.2246 | Val Loss: 0.2406
# Epoch 22/50 | Train Loss: 0.2196 | Val Loss: 0.2291
# Epoch 23/50 | Train Loss: 0.2137 | Val Loss: 0.2292
# Epoch 24/50 | Train Loss: 0.2087 | Val Loss: 0.2272
# Epoch 25/50 | Train Loss: 0.2077 | Val Loss: 0.2165
# Epoch 26/50 | Train Loss: 0.2013 | Val Loss: 0.2172
# Epoch 27/50 | Train Loss: 0.1977 | Val Loss: 0.2182
# Epoch 28/50 | Train Loss: 0.1949 | Val Loss: 0.2066
# Epoch 29/50 | Train Loss: 0.1903 | Val Loss: 0.2103
# Epoch 30/50 | Train Loss: 0.1886 | Val Loss: 0.1990
# Epoch 31/50 | Train Loss: 0.1842 | Val Loss: 0.2024
# Epoch 32/50 | Train Loss: 0.1814 | Val Loss: 0.1989
# Epoch 33/50 | Train Loss: 0.1786 | Val Loss: 0.2016
# Epoch 34/50 | Train Loss: 0.1751 | Val Loss: 0.1892
# Epoch 35/50 | Train Loss: 0.1733 | Val Loss: 0.1813
# Epoch 36/50 | Train Loss: 0.1694 | Val Loss: 0.1899
# Epoch 37/50 | Train Loss: 0.1664 | Val Loss: 0.1888
# Epoch 38/50 | Train Loss: 0.1669 | Val Loss: 0.1755
# Epoch 39/50 | Train Loss: 0.1639 | Val Loss: 0.1849
# Epoch 40/50 | Train Loss: 0.1609 | Val Loss: 0.1794
# Epoch 41/50 | Train Loss: 0.1608 | Val Loss: 0.1803
# Epoch 42/50 | Train Loss: 0.1582 | Val Loss: 0.1789
# Epoch 43/50 | Train Loss: 0.1558 | Val Loss: 0.1752
# Epoch 44/50 | Train Loss: 0.1544 | Val Loss: 0.1740
# Epoch 45/50 | Train Loss: 0.1535 | Val Loss: 0.1704
# Epoch 46/50 | Train Loss: 0.1490 | Val Loss: 0.1671
# Epoch 47/50 | Train Loss: 0.1484 | Val Loss: 0.1645
# Epoch 48/50 | Train Loss: 0.1489 | Val Loss: 0.1673
# Epoch 49/50 | Train Loss: 0.1470 | Val Loss: 0.1638
# Epoch 50/50 | Train Loss: 0.1441 | Val Loss: 0.1647

# %% [markdown]
# # Loss 그래프

# %%
plt.plot(train_loss_history, label="Train Loss")
plt.plot(val_loss_history, label="Val Loss")
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # 테스트 평가

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        preds = torch.argmax(outputs, dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(y_batch.numpy())

print("Classification Report:")
print(classification_report(all_labels, all_preds, digits=4))

# Confusion Matrix 시각화
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1,2,3], yticklabels=[0,1,2,3])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9957    1.0000    0.9978      1150
#            1     0.9513    0.8842    0.9166      1149
#            2     0.8666    0.8983    0.8822      1150
#            3     0.9434    0.9713    0.9572      1150
#
#     accuracy                         0.9385      4599
#    macro avg     0.9393    0.9385    0.9384      4599
# weighted avg     0.9392    0.9385    0.9384      4599
