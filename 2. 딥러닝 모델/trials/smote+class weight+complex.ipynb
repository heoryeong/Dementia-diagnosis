# %% [markdown]
# # 라이브러리 세팅

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import RandomOverSampler  # 임포트 추가
from imblearn.over_sampling import SMOTE
import seaborn as sns

# %% [markdown]
# # 데이터 로드, csv파일 호출 명령어에서 csv 파일명이 바뀌었습니다. 이에 맞춰 clustered_data2 파일을 다운받으셔야합니다.

# %%
df = pd.read_csv("clustered_data2.csv")

features = [
    'activity_score', 'activity_steps', 'activity_inactive', 'activity_high',
    'activity_score_meet_daily_targets', 'activity_score_move_every_hour',
    'activity_daily_movement', 'activity_total'
]
X = df[features].values.astype(np.float32)
y = df['risk_level'].values.astype(np.int64)

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %% [markdown]
# # 데이터 분할

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, stratify=y_resampled, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# # Tensor 변환 및 DataLoader 생성

# %%
train_dataset = TensorDataset(torch.tensor(X_train), torch.tensor(y_train))
val_dataset = TensorDataset(torch.tensor(X_val), torch.tensor(y_val))
test_dataset = TensorDataset(torch.tensor(X_test), torch.tensor(y_test))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64)
test_loader = DataLoader(test_dataset, batch_size=64)

# %% [markdown]
# # MLP 모델 정의

# %%
class RiskClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(8, 256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 4)
            )
    def forward(self, x):
        return self.net(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RiskClassifier().to(device)

# 클래스 가중치 계산
class_weights = torch.tensor([1 / np.sum(y_resampled == i) for i in np.unique(y_resampled)], dtype=torch.float32).to(device)
print("Class Weights:", class_weights)
# CrossEntropyLoss에 가중치 적용
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 학습 루프
epochs = 70
train_loss_history, val_loss_history = [], []

for epoch in range(epochs):
    model.train()
    epoch_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            val_outputs = model(X_val_batch)
            val_loss += criterion(val_outputs, y_val_batch).item()

    avg_train_loss = epoch_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)
    train_loss_history.append(avg_train_loss)
    val_loss_history.append(avg_val_loss)

    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Class Weights: tensor([0.0002, 0.0002, 0.0002, 0.0002])
# Epoch 1/70 | Train Loss: 0.6987 | Val Loss: 0.4403
# Epoch 2/70 | Train Loss: 0.4761 | Val Loss: 0.3711
# Epoch 3/70 | Train Loss: 0.4417 | Val Loss: 0.3500
# Epoch 4/70 | Train Loss: 0.4076 | Val Loss: 0.3123
# Epoch 5/70 | Train Loss: 0.3775 | Val Loss: 0.3050
# Epoch 6/70 | Train Loss: 0.3653 | Val Loss: 0.2882
# Epoch 7/70 | Train Loss: 0.3448 | Val Loss: 0.2761
# Epoch 8/70 | Train Loss: 0.3271 | Val Loss: 0.2760
# Epoch 9/70 | Train Loss: 0.3114 | Val Loss: 0.2419
# Epoch 10/70 | Train Loss: 0.3010 | Val Loss: 0.2533
# Epoch 11/70 | Train Loss: 0.2954 | Val Loss: 0.2323
# Epoch 12/70 | Train Loss: 0.2886 | Val Loss: 0.2306
# Epoch 13/70 | Train Loss: 0.2794 | Val Loss: 0.2160
# Epoch 14/70 | Train Loss: 0.2711 | Val Loss: 0.2024
# Epoch 15/70 | Train Loss: 0.2652 | Val Loss: 0.2096
# Epoch 16/70 | Train Loss: 0.2629 | Val Loss: 0.2066
# Epoch 17/70 | Train Loss: 0.2584 | Val Loss: 0.1988
# Epoch 18/70 | Train Loss: 0.2442 | Val Loss: 0.1949
# Epoch 19/70 | Train Loss: 0.2461 | Val Loss: 0.1805
# Epoch 20/70 | Train Loss: 0.2448 | Val Loss: 0.1898
# Epoch 21/70 | Train Loss: 0.2402 | Val Loss: 0.1770
# Epoch 22/70 | Train Loss: 0.2327 | Val Loss: 0.1749
# Epoch 23/70 | Train Loss: 0.2329 | Val Loss: 0.1727
# Epoch 24/70 | Train Loss: 0.2267 | Val Loss: 0.1759
# Epoch 25/70 | Train Loss: 0.2278 | Val Loss: 0.1825
# Epoch 26/70 | Train Loss: 0.2264 | Val Loss: 0.1765
# Epoch 27/70 | Train Loss: 0.2216 | Val Loss: 0.1748
# Epoch 28/70 | Train Loss: 0.2167 | Val Loss: 0.1858
# Epoch 29/70 | Train Loss: 0.2162 | Val Loss: 0.1842
# Epoch 30/70 | Train Loss: 0.2125 | Val Loss: 0.1773
# Epoch 31/70 | Train Loss: 0.2123 | Val Loss: 0.1654
# Epoch 32/70 | Train Loss: 0.2070 | Val Loss: 0.1614
# Epoch 33/70 | Train Loss: 0.2079 | Val Loss: 0.1671
# Epoch 34/70 | Train Loss: 0.2041 | Val Loss: 0.1631
# Epoch 35/70 | Train Loss: 0.2024 | Val Loss: 0.1679
# Epoch 36/70 | Train Loss: 0.2011 | Val Loss: 0.1592
# Epoch 37/70 | Train Loss: 0.2011 | Val Loss: 0.1611
# Epoch 38/70 | Train Loss: 0.1996 | Val Loss: 0.1509
# Epoch 39/70 | Train Loss: 0.1922 | Val Loss: 0.1643
# Epoch 40/70 | Train Loss: 0.1951 | Val Loss: 0.1571
# Epoch 41/70 | Train Loss: 0.1972 | Val Loss: 0.1533
# Epoch 42/70 | Train Loss: 0.1940 | Val Loss: 0.1536
# Epoch 43/70 | Train Loss: 0.1904 | Val Loss: 0.1608
# Epoch 44/70 | Train Loss: 0.1851 | Val Loss: 0.1628
# Epoch 45/70 | Train Loss: 0.1844 | Val Loss: 0.1452
# Epoch 46/70 | Train Loss: 0.1848 | Val Loss: 0.1533
# Epoch 47/70 | Train Loss: 0.1812 | Val Loss: 0.1523
# Epoch 48/70 | Train Loss: 0.1851 | Val Loss: 0.1492
# Epoch 49/70 | Train Loss: 0.1835 | Val Loss: 0.1474
# Epoch 50/70 | Train Loss: 0.1808 | Val Loss: 0.1449
# Epoch 51/70 | Train Loss: 0.1792 | Val Loss: 0.1375
# Epoch 52/70 | Train Loss: 0.1777 | Val Loss: 0.1467
# Epoch 53/70 | Train Loss: 0.1768 | Val Loss: 0.1449
# Epoch 54/70 | Train Loss: 0.1715 | Val Loss: 0.1421
# Epoch 55/70 | Train Loss: 0.1760 | Val Loss: 0.1487
# Epoch 56/70 | Train Loss: 0.1744 | Val Loss: 0.1470
# Epoch 57/70 | Train Loss: 0.1690 | Val Loss: 0.1406
# Epoch 58/70 | Train Loss: 0.1724 | Val Loss: 0.1423
# Epoch 59/70 | Train Loss: 0.1730 | Val Loss: 0.1354
# Epoch 60/70 | Train Loss: 0.1721 | Val Loss: 0.1414
# Epoch 61/70 | Train Loss: 0.1687 | Val Loss: 0.1455
# Epoch 62/70 | Train Loss: 0.1693 | Val Loss: 0.1389
# Epoch 63/70 | Train Loss: 0.1649 | Val Loss: 0.1381
# Epoch 64/70 | Train Loss: 0.1711 | Val Loss: 0.1394
# Epoch 65/70 | Train Loss: 0.1673 | Val Loss: 0.1452
# Epoch 66/70 | Train Loss: 0.1640 | Val Loss: 0.1495
# Epoch 67/70 | Train Loss: 0.1708 | Val Loss: 0.1435
# Epoch 68/70 | Train Loss: 0.1645 | Val Loss: 0.1361
# Epoch 69/70 | Train Loss: 0.1649 | Val Loss: 0.1395
# Epoch 70/70 | Train Loss: 0.1615 | Val Loss: 0.1354

# %% [markdown]
# # Loss 그래프

# %%
plt.plot(train_loss_history, label="Train Loss")
plt.plot(val_loss_history, label="Val Loss")
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # 테스트 평가

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        preds = torch.argmax(outputs, dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(y_batch.numpy())

print("Classification Report:")
print(classification_report(all_labels, all_preds, digits=4))

# Confusion Matrix 시각화
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1,2,3], yticklabels=[0,1,2,3])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9974    1.0000    0.9987      1150
#            1     0.9464    0.9217    0.9339      1149
#            2     0.9106    0.8852    0.8977      1150
#            3     0.9388    0.9870    0.9623      1150
#
#     accuracy                         0.9485      4599
#    macro avg     0.9483    0.9485    0.9481      4599
# weighted avg     0.9483    0.9485    0.9481      4599
