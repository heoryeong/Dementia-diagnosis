# %% [markdown]
# # 라이브러리 세팅

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import RandomOverSampler  # 임포트 추가
from imblearn.over_sampling import SMOTE
import seaborn as sns

# %% [markdown]
# # 데이터 로드, csv파일 호출 명령어에서 csv 파일명이 바뀌었습니다. 이에 맞춰 clustered_data2 파일을 다운받으셔야합니다.

# %%
df = pd.read_csv("clustered_data2.csv")

features = [
    'activity_score', 'activity_steps', 'activity_inactive', 'activity_high',
    'activity_score_meet_daily_targets', 'activity_score_move_every_hour',
    'activity_daily_movement', 'activity_total'
]
X = df[features].values.astype(np.float32)
y = df['risk_level'].values.astype(np.int64)

# %% [markdown]
# # 클래스 불균형 문제 해결을 위한 오버샘플링

# %%
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)

# %% [markdown]
# # 데이터 분할

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, stratify=y_resampled, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train, random_state=42)

# %% [markdown]
# # Tensor 변환 및 DataLoader 생성

# %%
train_dataset = TensorDataset(torch.tensor(X_train), torch.tensor(y_train))
val_dataset = TensorDataset(torch.tensor(X_val), torch.tensor(y_val))
test_dataset = TensorDataset(torch.tensor(X_test), torch.tensor(y_test))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64)
test_loader = DataLoader(test_dataset, batch_size=64)

# %% [markdown]
# # MLP 모델 정의

# %%
class RiskClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(8, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 4)  # 출력: 4단계 클래스
        )
    def forward(self, x):
        return self.net(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = RiskClassifier().to(device)

# 클래스 가중치 계산
class_weights = torch.tensor([1 / np.sum(y_resampled == i) for i in np.unique(y_resampled)], dtype=torch.float32).to(device)

# 손실 함수 및 옵티마이저 설정 (가중치 추가)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 학습 루프
epochs = 50
train_loss_history, val_loss_history = [], []

for epoch in range(epochs):
    model.train()
    epoch_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            val_outputs = model(X_val_batch)
            val_loss += criterion(val_outputs, y_val_batch).item()

    avg_train_loss = epoch_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)
    train_loss_history.append(avg_train_loss)
    val_loss_history.append(avg_val_loss)

    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/50 | Train Loss: 0.9488 | Val Loss: 0.6359
# Epoch 2/50 | Train Loss: 0.5377 | Val Loss: 0.4775
# Epoch 3/50 | Train Loss: 0.4453 | Val Loss: 0.4172
# Epoch 4/50 | Train Loss: 0.3989 | Val Loss: 0.3828
# Epoch 5/50 | Train Loss: 0.3671 | Val Loss: 0.3716
# Epoch 6/50 | Train Loss: 0.3422 | Val Loss: 0.3375
# Epoch 7/50 | Train Loss: 0.3229 | Val Loss: 0.3204
# Epoch 8/50 | Train Loss: 0.3062 | Val Loss: 0.3090
# Epoch 9/50 | Train Loss: 0.2936 | Val Loss: 0.3072
# Epoch 10/50 | Train Loss: 0.2810 | Val Loss: 0.2931
# Epoch 11/50 | Train Loss: 0.2709 | Val Loss: 0.2820
# Epoch 12/50 | Train Loss: 0.2618 | Val Loss: 0.2714
# Epoch 13/50 | Train Loss: 0.2540 | Val Loss: 0.2759
# Epoch 14/50 | Train Loss: 0.2461 | Val Loss: 0.2529
# Epoch 15/50 | Train Loss: 0.2396 | Val Loss: 0.2484
# Epoch 16/50 | Train Loss: 0.2337 | Val Loss: 0.2461
# Epoch 17/50 | Train Loss: 0.2301 | Val Loss: 0.2400
# Epoch 18/50 | Train Loss: 0.2222 | Val Loss: 0.2330
# Epoch 19/50 | Train Loss: 0.2172 | Val Loss: 0.2199
# Epoch 20/50 | Train Loss: 0.2124 | Val Loss: 0.2306
# Epoch 21/50 | Train Loss: 0.2082 | Val Loss: 0.2226
# Epoch 22/50 | Train Loss: 0.2058 | Val Loss: 0.2228
# Epoch 23/50 | Train Loss: 0.2025 | Val Loss: 0.2193
# Epoch 24/50 | Train Loss: 0.1950 | Val Loss: 0.2123
# Epoch 25/50 | Train Loss: 0.1922 | Val Loss: 0.2112
# Epoch 26/50 | Train Loss: 0.1894 | Val Loss: 0.1991
# Epoch 27/50 | Train Loss: 0.1843 | Val Loss: 0.2044
# Epoch 28/50 | Train Loss: 0.1831 | Val Loss: 0.1961
# Epoch 29/50 | Train Loss: 0.1783 | Val Loss: 0.1906
# Epoch 30/50 | Train Loss: 0.1744 | Val Loss: 0.1858
# Epoch 31/50 | Train Loss: 0.1712 | Val Loss: 0.1823
# Epoch 32/50 | Train Loss: 0.1698 | Val Loss: 0.1918
# Epoch 33/50 | Train Loss: 0.1689 | Val Loss: 0.1844
# Epoch 34/50 | Train Loss: 0.1651 | Val Loss: 0.2024
# Epoch 35/50 | Train Loss: 0.1643 | Val Loss: 0.1773
# Epoch 36/50 | Train Loss: 0.1613 | Val Loss: 0.1706
# Epoch 37/50 | Train Loss: 0.1600 | Val Loss: 0.1686
# Epoch 38/50 | Train Loss: 0.1562 | Val Loss: 0.1648
# Epoch 39/50 | Train Loss: 0.1544 | Val Loss: 0.1791
# Epoch 40/50 | Train Loss: 0.1528 | Val Loss: 0.1617
# Epoch 41/50 | Train Loss: 0.1521 | Val Loss: 0.1617
# Epoch 42/50 | Train Loss: 0.1488 | Val Loss: 0.1604
# Epoch 43/50 | Train Loss: 0.1491 | Val Loss: 0.1892
# Epoch 44/50 | Train Loss: 0.1453 | Val Loss: 0.1630
# Epoch 45/50 | Train Loss: 0.1461 | Val Loss: 0.1583
# Epoch 46/50 | Train Loss: 0.1450 | Val Loss: 0.1609
# Epoch 47/50 | Train Loss: 0.1421 | Val Loss: 0.1607
# Epoch 48/50 | Train Loss: 0.1415 | Val Loss: 0.1571
# Epoch 49/50 | Train Loss: 0.1391 | Val Loss: 0.1625
# Epoch 50/50 | Train Loss: 0.1382 | Val Loss: 0.1609

# %% [markdown]
# # Loss 그래프

# %%
plt.plot(train_loss_history, label="Train Loss")
plt.plot(val_loss_history, label="Val Loss")
plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # 테스트 평가

# %%
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        preds = torch.argmax(outputs, dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(y_batch.numpy())

print("Classification Report:")
print(classification_report(all_labels, all_preds, digits=4))

# Confusion Matrix 시각화
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1,2,3], yticklabels=[0,1,2,3])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9948    1.0000    0.9974      1150
#            1     0.9151    0.9191    0.9171      1149
#            2     0.8724    0.8678    0.8701      1150
#            3     0.9528    0.9487    0.9508      1150
#
#     accuracy                         0.9339      4599
#    macro avg     0.9338    0.9339    0.9338      4599
# weighted avg     0.9338    0.9339    0.9338      4599
